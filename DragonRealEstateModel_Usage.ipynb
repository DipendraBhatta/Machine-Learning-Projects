# %%
import numpy as np
from numpy import array

# %%
from joblib import load
model = load ("/content/Dragin.joblib")

# %%
import numpy as np

features = np.array([0.45541225, 0.56819041, 0.68704475, 0.61666984])

output = model.predict([features])

# Proper f-string formatting
print(f"The predicted MEDV for the given feature is $: {output[0]:.2f}")
# Out:
# The predicted MEDV for the given feature is $: 549801.00
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
